# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("GPT-generated", "Paper-text", "Merged")
penguin_means = {
    'GPT4': (100,100,100),
    'CLaMP-C': (98.07661864809245, 84.9058097198037, 89.23001424726928),
    'CLaMP-P': (99.43802437866076, 89.47285103688459, 91.23001424726928),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Composition understanding')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 120)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("GPT-generated", "Paper-text", "Merged")
penguin_means = {
    'GPT4': (12, 12, 12),
    'CLaMP-C': (26.09624821909134, 16.511002057938895, 89.23001424726928),
    'CLaMP-P': (, 89.47285103688459, 25.217666613899004),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Structure understanding')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 120)

plt.show()
